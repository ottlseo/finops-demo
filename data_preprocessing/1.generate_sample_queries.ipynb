# %% [markdown]
# # 1. Generate sample queries with descriptions
#
# > 이 노트북은 Git repo [dongjin-ml/text2sql](https://github.com/dongjin-ml/text2sql/blob/main/lab3_text2sql_schema_preparation/1.sample_queries.ipynb) 및 [kevmyung/text-to-sql-bedrock](https://github.com/kevmyung/text-to-sql-bedrock/blob/main/lab2_text2sql_schema_preparation/2.sample_queries.ipynb)를 참고하여, AWS CUR (Cost Usage Report) 데이터의 Text2SQL 작업에 필요한 추가 데이터를 준비하기 위해 작성되었습니다.
#
#
# 복잡한 데이터베이스에서 Text2SQL의 가장 어려운 작업은 쿼리 생성에 필요한 스키마를 선별하는 과정, 즉 Schema Linking 입니다.
#
# 현실의 기업 환경에서는 테이블/컬럼 이름이 의미를 축약하고 있어서 LLM이 이를 파악하기 힘들거나, 테이블/컬럼이 너무 많아서 모든 목록을 프롬프트에 담아 전달하는 것이 불가능한 경우가 많습니다.
#
# 이를 해결하기 위해, 우리 DB에 맞춰 스키마 설명 문서를 정제하고, LLM에 필요한 컨텍스트를 선별하여 제공하는 작업이 필요합니다.
#
# 이 노트북에서는, CUR 데이터 분석에 자주 사용되는 **[샘플 쿼리 23개](./input_data/cur_sample_queries.sql)를 기준으로** 각 쿼리가 어떤 상황에 사용되어야 하는지에 대한 description을 작성하여 LLM이 추후 text2sql 작업을 할 때 참고할 수 있는 데이터로 가공합니다. 또한 이를 키워드 및 vector 형태로 Opensearch에 인덱싱하여, 추후 text2sql 챗봇이 관련 쿼리를 검색하여 참고할 수 있도록 합니다.
#
# 전체 작업 흐름은 아래와 같이 이어갈 예정입니다. (이 노트북에서는 아래 그림의 1, 3 과정을 수행합니다. 2는 불필요하여 생략합니다)
#
#
# ![Intro](./img/schema-prep.png)

# %% [markdown]
# ## Step 0: OpenSearch 환경 설정

# %%
# !pip install -U opensearch-py langchain_aws langchain_community --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# safety-schemas 0.0.14 requires pydantic<2.10.0,>=2.6.0, but you have pydantic 2.11.5 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.

# %%
from libs.ssm import parameter_store
import boto3

pm = parameter_store('us-west-2')
secrets_manager = boto3.client('secretsmanager')

domain_endpoint = pm.get_params(key="opensearch_domain_endpoint", enc=False)
opensearch_domain_endpoint = f"https://{domain_endpoint}"

response = secrets_manager.get_secret_value(
    SecretId='opensearch_user_password'
)
secrets_dict = eval(response.get('SecretString'))

opensearch_user_id = secrets_dict['es.net.http.auth.user']
opensearch_user_password = secrets_dict['pwkey']

print(opensearch_domain_endpoint)
# Out:
# https://search-finops-domain-ldllkm5eqvjfy6uagpnepbsc4q.us-west-2.es.amazonaws.com

# %% [markdown]
# ## Step 1: Schema Description 문서 로드 (위 그림의 `1. Schema Loader`)
#
# 각 기업에는 Excel / CSV 등으로 스키마 설명 문서가 정의되어 있을 수 있습니다. 이를 Parsing하여 아래의 Schema Description 포맷으로 변경한다고 가정하겠습니다. ([cur_schema.json](./input_data/cur_schema.json)를 참고하세요.)
#
# ```
# {
#     "table_name": {
#         "table_desc": "Description of the table",
#         "cols": [
#             {
#                 "col": "Column Name 1",
#                 "col_desc": "Description of the column including PK info"
#             },
#             {
#                 "col": "Column Name 2",
#                 "col_desc": "Description of the column"
#             }
#         ]
#     }
# }
# ```
#
# 이와 같이 초기 설명 문서에는 테이블의 이름과 테이블에 대한 기본 설명, 컬럼 이름과 컬럼에 대한 설명이 포함되어야 합니다.

# %%
import json

file_path = './input_data/cur_schema.json'

with open(file_path, 'r', encoding='utf-8') as file:
    schema_description = json.load(file)

print(json.dumps(schema_description, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "cur.hourly_view_all": {
#             "table_desc": "AWS CUR 데이터를 시간별로 집계한 뷰",
#             "cols": [
#                 {
#                     "col": "product_code",
#                     "col_desc": "비용이 발생한 원천 AWS 서비스를 나타냅니다. 예를 들어 EC2에서 발생한 모든 비용(인스턴스 사용, 데이터 전송 등)은 'AmazonEC2'로 표시됩니다. 이는 어떤 서비스에서 비용이 발생했는지를 알려주는 식별자입니다."
#                 },
#                 {
#                     "col": "service",
#                     "col_desc": "실제 요금이 청구되는 AWS 서비스의 과금 카테고리입니다. 예를 들어 EC2 인스턴스 사용은 'AmazonEC2'로, EC2의 데이터 전송은 'AWSDataTransfer'로 청구됩니다. 이는 AWS 청구서 상의 서비스 구분을 나타냅니다."
#                 },
#                 {
#                     "col": "operation",
#                     "col_desc": "이 항목에서 다루는 특정 AWS 작업입니다. 이 항목의 구체적인 사용량에 대해 설명합니다. 예를 들어 RunInstances 값은 Amazon EC2 인스턴스 작업을 나타냅니다."
#                 },
#                 {
#                     "col": "charge_type",
# ...

# %% [markdown]
# #### 스키마 설명을 LLM을 이용해 증강합니다.
# 위와 같이 우리는 table과 column에 대한 아주 기본적인 정보를 담고 있는 [cur_schema.json](./input_data/cur_schema.json)이 있지만, 이 정보만으로 LLM이 Schema linking 작업을 정확하게 수행하기에 정보가 부족할 수 있습니다.
#
# 이에 우리는 LLM이 이를 증강하여 초기 설명문서를 생성하도록 합니다.
# 아래 셀은 `cur_schema.json`에 저장된 간단한 스키마 정보를 읽고 LLM 프롬프트 엔지니어링을 통해 증강하여, `input_data/enhanced_cur_schema.json`에 더 자세한 스키마 정보를 저장하도록 합니다.

# %%
import json
import os
from langchain_aws import ChatBedrock
from langchain_core.prompts.chat import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

_SYS_PROMPT_TEMPLATE_2 = """
당신은 AWS 비용 분석 전문가입니다. 제공된 컬럼 정보를 기반으로 더 자세한 설명과 활용 방안을 제시해주세요.

작업 지침:
- 컬럼의 세부적인 의미와 용도를 설명하세요
- 비용 분석과 최적화에서 이 컬럼을 어떻게 활용할 수 있는지 설명하세요
- AWS 비용 분석 관점에서 이 컬럼의 중요성을 설명하세요
- 컬럼명은 변경하지 마세요
- 아래 JSON 형식을 정확히 따르세요

출력 형식:
{
    "col": "컬럼명",
    "col_desc": "기본 설명",
    "detailed_info": {
        "purpose": "상세 용도 및 의미",
        "cost_analysis_usage": ["비용 분석 활용 방안 1", "활용 방안 2"]
    }
}
"""

_USER_PROMPT_TEMPLATE = """
<컬럼_정보>
컬럼명: {col}
현재설명: {col_desc}
</컬럼_정보>
"""

model_kwargs =  { 
    "max_tokens": 200000,
    "temperature": 0.0,
    "top_k": 250,
    "top_p": 1
}

# CUR 스키마 파일 로드
with open('./input_data/cur_schema.json', 'r', encoding='utf-8') as file:
    cur_schema = json.load(file)

if not os.path.exists('output_data'):
    os.makedirs('output_data')

usr_prompt = ChatPromptTemplate.from_template(_USER_PROMPT_TEMPLATE)

model_kwargs["system"] = _SYS_PROMPT_TEMPLATE_2
model = ChatBedrock(model_id="anthropic.claude-3-sonnet-20240229-v1:0", region_name='us-west-2', model_kwargs=model_kwargs)
chain = usr_prompt | model | StrOutputParser()

# 컬럼들에 대해 처리
enhanced_columns = []

for col_info in cur_schema[0]['cur.hourly_view_all']['cols']:
    response = chain.invoke({
        "col": col_info['col'],
        "col_desc": col_info['col_desc']
    })
    enhanced_columns.append(json.loads(response))

# 결과를 원본 구조와 동일하게 구성
enhanced_schema = [{
    'cur.hourly_view_all': {
        'table_desc': cur_schema[0]['cur.hourly_view_all']['table_desc'],
        'cols': enhanced_columns
    }
}]

# 결과 저장
with open('./input_data/enhanced_cur_schema.json', 'w', encoding='utf-8') as file:
    json.dump(enhanced_schema, file, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Step 2: SQL2Text 샘플 쿼리 변환 (위 그림의 `2. Query Translator`)
#
# 좋은 샘플 쿼리를 LLM에게 제공하는 것은 쿼리 작성 뿐만 아니라 Schema Linking에도 도움이 됩니다.
#
# 그러나, 대부분의 기업 환경에서 자주 사용되는 쿼리를 로그로 관리하고 있는 반면, (기존에 Text2SQL을 사용하지 않았기 때문에) 쿼리에 매칭되는 자연어 질문은 없습니다.
#
# Step 2에서는 자주 사용하는 쿼리들을 자연어 질문으로 변환하는 SQL2Text 과정을 진행합니다.

# %%
sql_file = 'input_data/cur_example_queries.sql'

with open(sql_file, 'r') as file:
    data = file.read()

queries = [query.strip() for query in data.split(';') if query.strip()]

for i, query in enumerate(queries, start=1):
    print(f"Query {i}:\n{query}\n{'-'*80}\n")
# Out:
# Query 1:
# SELECT linked_account_id, SUM(unblended_cost) FROM cur.hourly_view_all GROUP BY 1 ORDER BY 2 DESC
# --------------------------------------------------------------------------------
#
# Query 2:
# SELECT DATE_TRUNC('month', usage_date) as month, SUM(unblended_cost) FROM cur.hourly_view_all GROUP BY 1
# --------------------------------------------------------------------------------
#
# Query 3:
# SELECT product_code, COUNT(*) FROM cur.hourly_view_all WHERE unblended_cost > 100 GROUP BY product_code
# --------------------------------------------------------------------------------
#
# Query 4:
# SELECT product_code, SUM(unblended_cost) FROM cur.hourly_view_all GROUP BY product_code
# --------------------------------------------------------------------------------
#
# Query 5:
# ...

# %% [markdown]
# 쿼리를 해석하기 위해, 각 쿼리에 사용된 테이블/컬럼의 의미를 파악해야 합니다.
# 따라서, 각 쿼리에 사용된 테이블/컬럼 정보를 아래와 같이 추출합니다.
# ```
# {
#   "table": ["table1", "table2", ...],
#   "column": ["col1", "col2", ...]
# }
# ```
# 다음은 SQL 쿼리에 활용된 스키마 목록을 추출하는 LLM 요청 구문입니다.

# %%
SYS_PROMPT_TEMPLATE1 = """ 
You are an expert in extracting table names and column names from SQL queries. 
From the provided SQL query, extract all table names and column names used for SELECT, WHERE, and JOIN clauses, excluding asterisks ("*"). 
Ensure that the response is in a valid JSON format that can be used directly with json.load(). 
Skip the preamble and only provide the answer in a JSON document:

{
  "table": ["table1", "table2", ...],
  "column": ["col1", "col2", ...]
}

<example>
SQL:
SELECT * from LOGIS_ADMIN.IAWD_TB_DCBSCD_BASISLC_M 
where basis_lclsf_cd_nm like '%예약구분%'
LIMIT 200;

{
  "table": ["IAWD_TB_DCBSCD_BASISLC_M"],
  "column": ["basis_lclsf_cd_nm"]
}
</example>
"""

USR_PROMPT_TEMPLATE1="""
SQL: {sql}
"""

# %%
from langchain_aws import ChatBedrock
from langchain_core.prompts.chat import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model_kwargs =  { 
    "max_tokens": 200000,
    "temperature": 0.0,
    "top_k": 250,
    "top_p": 1
}

# %%
model_kwargs["system"] = SYS_PROMPT_TEMPLATE1
model1 = ChatBedrock(model_id="us.anthropic.claude-3-5-sonnet-20241022-v2:0", region_name='us-west-2', model_kwargs=model_kwargs)
prompt1 = ChatPromptTemplate.from_template(USR_PROMPT_TEMPLATE1)

chain1 = prompt1 | model1 | StrOutputParser()

# %% [markdown]
# 예를 들어 아래 쿼리에 사용된 스키마를 추출해보겠습니다.
#
# ```SELECT usage_date, operation, SUM(usage_quantity) as usage_amount FROM cur.hourly_view_all WHERE operation IN ('RunInstances', 'CreateVolume', 'CreateSnapshot') GROUP BY usage_date, operation ORDER BY usage_date DESC```

# %%
sql = queries[8].strip()
response = chain1.invoke({"sql": sql})
used_schema = json.loads(response)
print(used_schema)
# Out:
# {'table': ['hourly_view_all'], 'column': ['usage_date', 'operation', 'usage_quantity']}

# %% [markdown]
# #### 이제 이 쿼리에 사용된 스키마 설명을 조회합니다.

# %%
def extract_descriptions(table_info, tables, columns):
    tables_lower = {table.lower() for table in tables}
    columns_lower = {column.lower() for column in columns}
    
    description = {
        "table": {},
        "column": {}
    }
    
    for cur_schema in table_info:
        for table_name, table_info in cur_schema.items():
            description["table"][table_name] = table_info["table_desc"]
            for col in table_info["cols"]:
                col_name = col["col"]
                if col_name.lower() in columns_lower:
                    description["column"][col_name] = col["col_desc"]
    return description

# %%
extracted_description = extract_descriptions(schema_description, used_schema['table'], used_schema['column'])
print(extracted_description)
# Out:
# {'table': {'cur.hourly_view_all': 'AWS CUR 데이터를 시간별로 집계한 뷰'}, 'column': {'operation': '이 항목에서 다루는 특정 AWS 작업입니다. 이 항목의 구체적인 사용량에 대해 설명합니다. 예를 들어 RunInstances 값은 Amazon EC2 인스턴스 작업을 나타냅니다.', 'usage_date': '이 항목의 시작 날짜와 시간(UTC)입니다. 포괄적입니다. 형식은 YYYY-MM-DDTHH:mm:ssZ입니다.', 'usage_quantity': '지정된 기간 동안 발생한 사용량의 총합입니다.'}}

# %% [markdown]
# #### 이제 쿼리에 대한 자연어 변환을 요청합니다.

# %%
SYS_PROMPT_TEMPLATE2 = """ 
당신은 AWS CUR(Cost and Usage Report) 데이터 분석 전문가입니다.
주어진 SQL 쿼리의 의도와 비즈니스 목적을 파악하여 자연스러운 한국어로 설명해주세요.

작업 지침:
- CUR 데이터의 특성을 고려한 실무적인 관점에서 설명
- AWS 비용 최적화 및 분석 관점에서 해당 쿼리의 목적 설명
- 쿼리가 도출하는 데이터의 실제 활용 방안 제시
- 비용 분석/최적화 담당자가 이해하기 쉬운 자연스러운 한국어로 표현
- 모든 조건절과 집계 방식의 비즈니스 의미를 포함
- 불필요한 서론 없이 핵심적인 내용만 간단명료하게 서술

출력 형식:
1. 요청: [실무자가 이 데이터를 요청하는 실제 상황에 사용될 자연어 질문]
2. 비즈니스 목적: [이 데이터가 비용 최적화에 기여하는 방식 및 데이터 기반 의사결정 및 조치 사항]
3. 연관 분석: [후속 분석이나 타 지표와의 연계 방안]
"""

USR_PROMPT_TEMPLATE2="""
<쿼리_설명>
{description}
</쿼리_설명>

CUR 쿼리문: {sql}
"""

# %%
model_kwargs["system"] = SYS_PROMPT_TEMPLATE2
model2 = ChatBedrock(model_id="us.anthropic.claude-3-5-sonnet-20241022-v2:0", region_name='us-west-2', model_kwargs=model_kwargs)
prompt2 = ChatPromptTemplate.from_template(USR_PROMPT_TEMPLATE2)
chain2 = prompt2 | model2 | StrOutputParser()

# %% [markdown]
# #### 자연어 질문을 생성하는 프롬프트는 아래 형식으로 LLM에 전달됩니다.

# %%
print(SYS_PROMPT_TEMPLATE2)
print(prompt2.format(description=extracted_description, sql=queries[8]))
# Out:
#
# 당신은 AWS CUR(Cost and Usage Report) 데이터 분석 전문가입니다.
# 주어진 SQL 쿼리의 의도와 비즈니스 목적을 파악하여 자연스러운 한국어로 설명해주세요.
#
# 작업 지침:
# - CUR 데이터의 특성을 고려한 실무적인 관점에서 설명
# - AWS 비용 최적화 및 분석 관점에서 해당 쿼리의 목적 설명
# - 쿼리가 도출하는 데이터의 실제 활용 방안 제시
# - 비용 분석/최적화 담당자가 이해하기 쉬운 자연스러운 한국어로 표현
# - 모든 조건절과 집계 방식의 비즈니스 의미를 포함
# - 불필요한 서론 없이 핵심적인 내용만 간단명료하게 서술
#
# 출력 형식:
# 1. 요청: [실무자가 이 데이터를 요청하는 실제 상황에 사용될 자연어 질문]
# 2. 비즈니스 목적: [이 데이터가 비용 최적화에 기여하는 방식 및 데이터 기반 의사결정 및 조치 사항]
# 3. 연관 분석: [후속 분석이나 타 지표와의 연계 방안]
#
# Human:
# <쿼리_설명>
# {'table': {'cur.hourly_view_all': 'AWS CUR 데이터를 시간별로 집계한 뷰'}, 'column': {'operation': '이 항목에서 다루는 특정 AWS 작업입니다. 이 항목의 구체적인 사용량에 대해 설명합니다. 예를 들어 RunInstances 값은 Amazon EC2 인스턴스 작업을 나타냅니다.', 'usage_date': '이 항목의 시작 날짜와 시간(UTC)입니다. 포괄적입니다. 형식은 YYYY-MM-DDTHH:mm:ssZ입니다.', 'usage_quantity': '지정된 기간 동안 발생한 사용량의 총합입니다.'}}
# </쿼리_설명>
#
# ...

# %%
response = chain2.invoke({"sql": queries[8], "description": extracted_description})
print(response)
# Out:
# 1. 요청:
# "EC2 관련 주요 작업(인스턴스 실행, 볼륨 생성, 스냅샷 생성)의 일별 사용량 추이를 확인하고 싶습니다."
#
# 2. 비즈니스 목적:
# - EC2 인스턴스, EBS 볼륨, 스냅샷의 생성 패턴을 시계열로 분석하여 리소스 사용 현황 파악
# - 불필요한 리소스 생성이나 비정상적인 사용량 스파이크를 감지하여 비용 낭비 요소 식별
# - 특히 자동화된 스냅샷 정책이나 볼륨 생성 패턴이 적절한지 검토 가능
# - 시간대별 워크로드 패턴을 분석하여 리소스 프로비저닝 최적화 기회 발굴
#
# 3. 연관 분석:
# - 사용량과 실제 비용을 매칭하여 비용 효율성 분석
# - 인스턴스 타입별, 리전별로 세분화하여 더 상세한 패턴 파악 가능
# - Auto Scaling 이벤트나 백업 정책과 연계하여 자동화된 작업의 적절성 검토
# - 비즈니스 피크 타임과 리소스 생성 패턴을 비교하여 용량 계획 수립에 활용

# %% [markdown]
# #### 다음 쿼리에 대한 자연어 설명은 LLM에 의해 위와 같이 정의되었습니다.
#
# ```SELECT usage_date, operation, SUM(usage_quantity) as usage_amount FROM cur.hourly_view_all WHERE operation IN ('RunInstances', 'CreateVolume', 'CreateSnapshot') GROUP BY usage_date, operation ORDER BY usage_date DESC```
#
# #### 아래는 위 과정을 모든 SQL 쿼리에 대해 반복하는 스크립트입니다. (약 1~2분 소요됩니다)

# %%
import os

def query_translation(output_file_path, table_info, queries, chain1, chain2):
    # output_file_path 디렉토리가 없으면 생성
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    
    if os.path.exists(output_file_path):
        os.remove(output_file_path)

    with open(output_file_path, 'a') as output_file:
        for query in queries:
            sql = query.strip()
            
            try:
                response = chain1.invoke({"sql": sql})
                schema = json.loads(response)
            except json.JSONDecodeError:
                print(response)
                time.sleep(1)  

            description = extract_descriptions(table_info, schema["table"], schema["column"])
            
            input = chain2.invoke({"sql": sql, "description": description})
            # Write input and query to the file in JSON format
            data = {"input": input, "query": sql}
            output_file.write(json.dumps(data, ensure_ascii=False) + "\n")

FILE_PATH_1 = './output_data/cur_example_queries_temp.jsonl'

query_translation(FILE_PATH_1, schema_description, queries, chain1, chain2)

# %% [markdown]
# #### 쿼리 변환이 완료된 결과는 `./output_data/cur_example_queries_temp.jsonl` 파일에 저장되어 있습니다.

# %%
with open(FILE_PATH_1, 'r') as file:
    for line in file:
        data = json.loads(line)
        print(data)
# Out:
# {'input': '1. 요청:\n"각 멤버 계정별 총 AWS 사용 비용이 얼마인지 확인하고, 비용이 높은 계정부터 정렬해서 보여주세요."\n\n2. 비즈니스 목적:\n- 조직 내 AWS 계정별 비용 책임 소재를 파악하고 비용 할당을 명확히 하기 위한 기초 데이터 확보\n- 비용 발생이 큰 계정을 식별하여 우선적인 비용 최적화 대상 선정\n- 부서/팀별 예산 관리 및 비용 초과 여부 모니터링\n- 할인 혜택(RI/SP) 적용 전 실제 리소스 사용량 기반 비용 현황 파악\n\n3. 연관 분석:\n- 높은 비용이 발생하는 계정의 세부 리소스 사용 패턴 분석\n- 계정별 비용 추세를 시계열로 확장하여 비정상적인 비용 증가 탐지\n- 계정별 RI/SP 커버리지 분석을 통한 추가 비용 절감 기회 발굴\n- 부서별 비용 센터 매핑을 통한 조직 단위 비용 관리 체계 수립', 'query': 'SELECT linked_account_id, SUM(unblended_cost) FROM cur.hourly_view_all GROUP BY 1 ORDER BY 2 DESC'}
# ...

# %% [markdown]
# ## Step 3: 샘플 쿼리 벡터 임베딩 및 OpenSearch 저장

# %% [markdown]
# 이제 <자연어 질문 & SQL 쿼리> 조합의 자연어 질문을 벡터로 임베딩하여, 사용자 질문과 유사한 SQL 쿼리를 찾아내기 용이하도록 저장해야 합니다.
# 먼저 아래 구문을 이용해 OpenSearch 환경을 초기화합니다. (연결 생성 및 Index 초기화)
#
#
#
# > #### 혹시 nori tokenizer 관련 오류가 발생했나요?
# > `RequestError: RequestError(400, 'illegal_argument_exception', 'Unknown tokenizer type [nori]'`
# >
# > 위 오류가 발생한 경우, 아래 단계를 따라 nori tokenizer를 설치한 후 다시 실행해주세요.
# > 1. AWS Console > OpenSearch Service로 이동
# > 2. 해당 도메인 선택: `finops-rag-test`
# > 3. Actions > Edit cluster configuration
# > 4. Customize additional settings 선택
# > 5. Advanced options에서 다음 추가: plugin.mandatory: analysis-nori
# > 6. Save changes 선택
# >
# > nori는 한국어 형태소 분석을 위한 토크나이저입니다. nori에 대한 자세한 정보가 궁금하시다면 [다음 블로그](https://aws.amazon.com/ko/blogs/tech/amazon-opensearch-service-korean-nori-plugin-for-analysis/)를 참고하세요.

# %%
import yaml
from opensearchpy import OpenSearch, RequestsHttpConnection
INDEX_NAME = "sample_queries"

def load_opensearch_config():
    with open("./libs/opensearch.yml", 'r', encoding='utf-8') as file:
        return yaml.safe_load(file)

def init_opensearch(config):
    mapping = {"settings": config['settings'], "mappings": config['mappings-sql']}
    endpoint = opensearch_domain_endpoint
    http_auth = (opensearch_user_id, opensearch_user_password)

    os_client = OpenSearch(
            hosts=[{'host': endpoint.replace("https://", ""),'port': 443}],
            http_auth=http_auth, 
            use_ssl=True,
            verify_certs=True,
            timeout=300,
            connection_class=RequestsHttpConnection
    )

    create_os_index(os_client, mapping)
    return os_client

def create_os_index(os_client, mapping):
    exists = os_client.indices.exists(index=INDEX_NAME)

    if exists:
        os_client.indices.delete(index=INDEX_NAME)
        print("Existing index has been deleted. Create new one.")
    else:
        print("Index does not exist, Create one.")

    os_client.indices.create(index=INDEX_NAME, body=mapping)

config = load_opensearch_config()
os_client = init_opensearch(config)
# Out:
# Existing index has been deleted. Create new one.

# %% [markdown]
# 이제 앞에 만들었던 <자연어 질문 & SQL 쿼리>를 벡터 임베딩으로 변환하고, OpenSearch에 bulk indexing 할 수 있는 Data-Action 포맷으로 구성합니다.

# %%
from langchain_community.embeddings import BedrockEmbeddings

FILE_PATH_2 = './output_data/cur_example_queries.jsonl'
emb_model = BedrockEmbeddings(model_id="amazon.titan-embed-text-v2:0", region_name='us-west-2', model_kwargs={"dimensions":1024}) 

def input_embedding(input_file_path, output_file_path, emb_model):
    # 기존 최대 ID 확인
    max_id = -1
    if os.path.exists(output_file_path):
        with open(output_file_path, 'r') as f:
            for line in f:
                data = json.loads(line)
                if '_id' in data.get('index', {}):
                    max_id = max(max_id, int(data['index']['_id']))
    
    num = max_id + 1  # 기존 최대 ID 다음부터 시작
    
    with open(input_file_path, 'r') as input_file, open(output_file_path, 'a') as output_file:
        for line in input_file:
            data = json.loads(line)
            input = data['input']
            query = data['query']
            
            # Data part
            body = { "input": input, "query": query, "input_v": emb_model.embed_query(input) }

            # Action part
            action = { "index": { "_index": INDEX_NAME, "_id": str(num) } }

            # Write action and body to the file in correct bulk format
            output_file.write(json.dumps(action, ensure_ascii=False) + "\n")
            output_file.write(json.dumps(body, ensure_ascii=False) + "\n")

            num += 1    

input_embedding(FILE_PATH_1, FILE_PATH_2, emb_model)
# Out:
# /tmp/ipykernel_6574/627612398.py:4: LangChainDeprecationWarning: The class `BedrockEmbeddings` was deprecated in LangChain 0.2.11 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-aws package and should be used instead. To use it run `pip install -U :class:`~langchain-aws` and import as `from :class:`~langchain_aws import BedrockEmbeddings``.
#   emb_model = BedrockEmbeddings(model_id="amazon.titan-embed-text-v2:0", region_name='us-west-2', model_kwargs={"dimensions":1024})

# %% [markdown]
# #### 위 코드를 실행한 뒤 `./output_data/cur_example_queries.jsonl` 파일을 열어보면, 변환된 임베딩을 확인할 수 있습니다.

# %%
with open(FILE_PATH_2, 'r') as file:
    bulk_data = file.read()
        
response = os_client.bulk(body=bulk_data)
if response["errors"]:
    print("There were errors during bulk indexing:")
    for item in response["items"]:
        if 'index' in item and item['index']['status'] >= 400:
            print(f"Error: {item['index']['error']['reason']}")
else:
    print("Bulk-inserted all items successfully.")
# Out:
# Bulk-inserted all items successfully.

# %% [markdown]
# #### 이제 OpenSearch에 저장을 완료했습니다.

# %% [markdown]
# ## (Optional) Step 4: 자주 발생하는 오류 케이스를 방지하기 위해 example queries에 쿼리 추가하기
#
# 이제 Text2Sql 테스트를 진행해보았을 때, 위에서 인덱싱한 샘플 쿼리를 참고하여 대부분의 쿼리를 잘 생성합니다.
#
# 그러나, '인스턴스 타입'과 관련한 질문 (e.g. 비용을 가장 많이 사용한 EC2 인스턴스 타입 5가지를 알려주세요)을 했을 때, 매번 다음과 같은 오류가 발생합니다:
# `INVALID_FUNCTION_ARGUMENT: Index must be greater than zero`
#
# Athena는 presto 기반의 SQL 문법을 사용하는데, 대부분 presto의 문법을 따르지만 종종 문법이 다른 경우가 있습니다. 이 때 LLM이 이를 캐치하지 못해 위 예시에서처럼 Athena에서 지원하지 않는 presto 문법 (SPLIT_PART에 음수 인덱스 사용)을 사용하여 오류가 발생하는 것입니다.
#
# 이번 step에서는, 자주 발생하는 오류 케이스를 발견했을 때 같은 케이스를 방지하기 위해, **기존 인덱스(sample_queries)에 새로운 쿼리를 추가**함으로써 정확도를 높이는 작업을 수행합니다.

# %%
new_queries = [
    "SELECT SPLIT_PART(usage_type, ':', 2) as instance_type, SUM(unblended_cost) as total_cost FROM cur.hourly_view_allWHERE usage_type LIKE '%BoxUsage%' AND usage_date >= CAST('2024-07-01' AS TIMESTAMP) AND usage_date < CAST('2024-08-01' AS TIMESTAMP) AND service = 'AmazonEC2' GROUP BY SPLIT_PART(usage_type, ':', 2) ORDER BY total_cost DESC LIMIT 5;",
    "SELECT SPLIT_PART(usage_type, ':', 2) as instance_type, pricing_term, SUM(usage_quantity) as total_hours, SUM(unblended_cost) as total_cost FROM cur.hourly_view_all WHERE usage_type LIKE '%BoxUsage%'AND service = 'AmazonEC2'GROUP BY SPLIT_PART(usage_type, ':', 2), pricing_term ORDER BY total_cost DESC;",
    "SELECT region, SPLIT_PART(usage_type, ':', 2) as instance_type, SUM(usage_quantity) as total_hours FROM cur.hourly_view_all WHERE usage_type LIKE '%BoxUsage%'AND service = 'AmazonEC2'AND usage_date >= CURRENT_DATE - INTERVAL '3' MONTHGROUP BY region, SPLIT_PART(usage_type, ':', 2) ORDER BY region, total_hours DESC;",
    "SELECT SPLIT_PART(usage_type, ':', 2) as instance_type, SUM(unblended_cost)/SUM(usage_quantity) as cost_per_hour FROM cur.hourly_view_all WHERE usage_type LIKE '%BoxUsage%'AND service = 'AmazonEC2'GROUP BY SPLIT_PART(usage_type, ':', 2) ORDER BY cost_per_hour DESC LIMIT 10;",
    "SELECT resource_id, SPLIT_PART(usage_type, ':', 2) as instance_type, MIN(usage_date) as creation_date, SUM(unblended_cost) as total_cost FROM cur.hourly_view_all WHERE usage_type LIKE '%BoxUsage%'AND service = 'AmazonEC2'AND usage_date >= DATE_TRUNC('month', CURRENT_DATE) GROUP BY resource_id, SPLIT_PART(usage_type, ':', 2) ORDER BY creation_date ASC;"
]

FILE_PATH_3 = './output_data/cur_example_queries_02_temp.jsonl'
FILE_PATH_4 = './output_data/cur_example_queries_02.jsonl'

# %%
# Write description 
query_translation(FILE_PATH_3, schema_description, new_queries, chain1, chain2)

# Embedding & OpenSearch indexing
input_embedding(FILE_PATH_3, FILE_PATH_4, emb_model)

# Check
with open(FILE_PATH_4, 'r') as file:
    bulk_data = file.read()
        
response = os_client.bulk(body=bulk_data)
if response["errors"]:
    print("There were errors during bulk indexing:")
    for item in response["items"]:
        if 'index' in item and item['index']['status'] >= 400:
            print(f"Error: {item['index']['error']['reason']}")
else:
    print("Bulk-inserted all items successfully.")
# Out:
# Bulk-inserted all items successfully.

# %%
# SYS_PROMPT_TEMPLATE3 = """ 
# 당신은 AWS CUR(Cost and Usage Report) 데이터 분석 전문가입니다.

# <자연어질문>
# 2024년 7월 한 달 동안 비용을 가장 많이 사용한 AmazonEC2 인스턴스 타입 5가지를 알려주세요. 비용이 높은 순서대로 알려주세요.
# </자연어질문>

# <실패하는쿼리>
# ```sql 
# SELECT 
#     SPLIT_PART(usage_type, ':', -1) as instance_type,
#     SUM(unblended_cost) as total_cost
# FROM cur.hourly_view_all
# WHERE usage_type LIKE '%BoxUsage%'
# AND usage_date >= CAST('2024-07-01' AS TIMESTAMP)
# AND usage_date < CAST('2024-08-01' AS TIMESTAMP)
# AND service = 'AmazonEC2'
# GROUP BY SPLIT_PART(usage_type, ':', -1)
# ORDER BY total_cost DESC
# LIMIT 5;
# ```
# </실패하는쿼리>

# <성공하는쿼리>
# ```sql
# SELECT 
#     SPLIT_PART(usage_type, ':', 2) as instance_type,
#     SUM(unblended_cost) as total_costFROM cur.hourly_view_all WHERE usage_type LIKE '%BoxUsage%'
# AND usage_date >= CAST('2024-07-01' AS TIMESTAMP)AND usage_date < CAST('2024-08-01' AS TIMESTAMP)AND service = 'AmazonEC2'
# GROUP BY SPLIT_PART(usage_type, ':', 2)ORDER BY total_cost DESC
# LIMIT 5;
# ```
# </성공하는쿼리>

# <자연어질문>에 대해 CUR 데이터로 Athena 용 SQL쿼리를 생성하는데, Athena에서 <실패하는쿼리>와 <성공하는쿼리>가 있어. 
# 실패하는 이유는 Athena 쿼리에서는 index로 음수를 쓸 수 없기 때문이야. 이 오류상황과 관련해서 '자연어 질문'과 '성공하는 쿼리' 쌍 5개를 만들어줘. CUR 데이터에 맞게 만들어줘야 해.

# <출력 형식>
# 1. 요청: [실무자가 이 데이터를 요청하는 실제 상황에 사용될 자연어 질문]
# 2. SQL 쿼리
# </출력 형식>
# """

# USR_PROMPT_TEMPLATE3="""
# <쿼리_설명>
# {description}
# </쿼리_설명>

# CUR 쿼리문: {sql}
# """
